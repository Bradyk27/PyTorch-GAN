# %%
import pandas as pd

# %%
df = pd.read_csv("Loss_Data.csv").drop(df.columns[0], axis=1)

# %%
print(df)
# Out:
#       Epoch  D_Adv_Real  D_Aux_Real  D_Adv_Fake  D_Aux_Fake    acc     G_Adv  \
# 0       0.0    0.719657    2.197769    0.667333    2.196635  13.28  0.719658
# 1       0.0    0.719038    2.198687    0.667922    2.197310   9.38  0.719041
# 2       0.0    0.718496    2.196925    0.668441    2.197709  16.41  0.718497
# 3       0.0    0.717943    2.196303    0.668965    2.197326  13.28  0.717941
# 4       0.0    0.717392    2.198068    0.669490    2.196409   9.38  0.717393
# ...     ...         ...         ...         ...         ...    ...       ...
# 6795  199.0    0.693146    2.120997    0.693148    1.388008  63.28  0.693146
# 6796  199.0    0.693148    2.090557    0.693147    1.383895  64.06  0.693148
# 6797  199.0    0.693147    2.137510    0.693148    1.375744  60.16  0.693147
# 6798  199.0    0.693147    2.115573    0.693148    1.379664  60.94  0.693147
# 6799  199.0    0.693148    2.126152    0.693147    1.377121  59.38  0.693148
#
#          G_Aux
# 0     2.197007
# 1     2.197291
# 2     2.197866
# 3     2.197436
# 4     2.196367
# ...        ...
# 6795  1.382050
# 6796  1.388025
# 6797  1.374380
# 6798  1.374068
# 6799  1.372904
#
# [6800 rows x 8 columns]

# %%
new_df = pd.DataFrame(df.loc[df['Epoch'] == 0].mean()).transpose()
for i in range(1,200):
    temp = df.loc[df['Epoch'] == i].mean()
    new_df.loc[len(new_df)] = temp
    
col = new_df.loc[:, ['D_Adv_Real', 'D_Adv_Fake']]
print(col)
new_df['D_Adv'] = col.mean(1)

col = new_df.loc[:, ['D_Aux_Real', 'D_Aux_Fake']]
print(col)
new_df['D_Aux'] = col.mean(1)
# Out:
#      D_Adv_Real  D_Adv_Fake
# 0      0.711115    0.675535
# 1      0.698288    0.688057
# 2      0.693666    0.692648
# 3      0.692880    0.693461
# 4      0.693485    0.693552
# ..          ...         ...
# 195    0.693147    0.693147
# 196    0.693123    0.693180
# 197    0.693175    0.693120
# 198    0.693148    0.693146
# 199    0.693147    0.693147
#
# [200 rows x 2 columns]
#      D_Aux_Real  D_Aux_Fake
# 0      2.197622    2.197225
# 1      2.197382    2.197346
# 2      2.197076    2.197289
# 3      2.196135    2.196661
# 4      2.192979    2.176448
# ..          ...         ...
# 195    2.119372    1.378269
# 196    2.120815    1.377057
# 197    2.118426    1.376883
# 198    2.120267    1.379621
# 199    2.119006    1.378184
#
# [200 rows x 2 columns]

# %%
print(new_df)
# Out:
#      Epoch  D_Adv_Real  D_Aux_Real  D_Adv_Fake  D_Aux_Fake        acc  \
# 0      0.0    0.711115    2.197622    0.675535    2.197225  10.272059
# 1      1.0    0.698288    2.197382    0.688057    2.197346  11.030294
# 2      2.0    0.693666    2.197076    0.692648    2.197289  11.259118
# 3      3.0    0.692880    2.196135    0.693461    2.196661  11.993824
# 4      4.0    0.693485    2.192979    0.693552    2.176448  16.543824
# ..     ...         ...         ...         ...         ...        ...
# 195  195.0    0.693147    2.119372    0.693147    1.378269  61.810588
# 196  196.0    0.693123    2.120815    0.693180    1.377057  61.282353
# 197  197.0    0.693175    2.118426    0.693120    1.376883  61.649706
# 198  198.0    0.693148    2.120267    0.693146    1.379621  61.465882
# 199  199.0    0.693147    2.119006    0.693147    1.378184  61.467059
#
#         G_Adv     G_Aux     D_Adv     D_Aux
# 0    0.711115  2.197243  0.693325  2.197424
# 1    0.698287  2.197331  0.693173  2.197364
# 2    0.693664  2.197315  0.693157  2.197183
# 3    0.692852  2.196701  0.693170  2.196398
# 4    0.693128  2.176081  0.693519  2.184714
# ..        ...       ...       ...       ...
# 195  0.693147  1.380027  0.693147  1.748821
# 196  0.693123  1.377148  0.693151  1.748936
# 197  0.693175  1.377179  0.693148  1.747654
# 198  0.693148  1.381992  0.693147  1.749944
# 199  0.693147  1.377646  0.693147  1.748595
#
# [200 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot('Epoch', 'D_Adv', data = new_df.head(60), color="red")
plt.plot('Epoch', 'G_Adv', data = new_df.head(60), color="blue")
plt.xlabel("Epoch")
plt.legend()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.plot('Epoch', 'G_Aux', data = new_df, color="red")
plt.plot('Epoch', 'D_Aux', data = new_df, color="blue")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.plot('Epoch', 'acc', data = new_df, color="red")
plt.xlabel("Epoch")
plt.legend()

# %%
new_df['acc'].max()
# Out:
# 61.926470588235304

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
def flatten(t):
    return [item for sublist in t for item in sublist]
# %matplotlib notebook
import random

# %%
fs = np.load('skels/400_data.npy')
x_cords = fs[0][0]
y_cords = fs[0][1]
z_cords = fs[0][2]

x = flatten(x_cords[0].tolist())
y = flatten(y_cords[0].tolist())
z = flatten(z_cords[0].tolist())

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fs = np.load('train_data.npy')
i = random.randint(0, len(fs))
x_cords = fs[i][0]
y_cords = fs[i][1]
z_cords = fs[i][2]

x = flatten(x_cords[0].tolist())
y = flatten(y_cords[0].tolist())
z = flatten(z_cords[0].tolist())
print(x)
print(y)
print(z)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# [2.3624510765075684, 2.2995481491088867, 1.1962810754776, 1.1759620904922485, -0.03405246511101723, -0.033988967537879944, 0.03405246511101723, 0.0339980386197567, -1.1198399066925049, -1.1177444458007812, -1.8594151735305786, -1.8576689958572388, -2.5457708835601807]
# [-0.23966893553733826, -0.09998036175966263, -0.37597402930259705, 0.10079674422740936, -0.8513116240501404, 0.5778124332427979, -0.9875214695930481, 0.9859431385993958, -0.9162326455116272, 0.6435498595237732, -0.5071132183074951, 0.10132739692926407, -0.10183084011077881]
# [57.85723114013672, 56.31672286987305, 57.757598876953125, 56.77657699584961, 57.542999267578125, 57.435699462890625, 57.542999267578125, 57.451026916503906, 57.343727111816406, 57.23643112182617, 57.12913131713867, 57.07548141479492, 57.35905838012695]
# <img src="data:image/png;base64,..." width="640">
